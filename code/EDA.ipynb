# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os

# %% [markdown]
# ### Direcotry Structure

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
cwd = os.getcwd()
parent = os.path.dirname(cwd)
print(parent)
# Out:
# D:\MSU\CMSE 831 Project

# %% [markdown]
# ### View

# %%
# Contains relevance between movies and their tagging by users
# D:\MSU\CMSE 831 Project
genome_scores = pd.read_csv(f'{parent}\data\genome_scores.csv')
genome_scores.sample(5)
# Out:
#          movieId  tagId  relevance
# 2847873     2852    802    0.02500
# 4520366     4529    471    0.23575
# 7963152    26819    601    0.16675
# 6735307     7090     20    0.38125
# 2951974     2948   1127    0.06650

# %%
genome_tags = pd.read_csv(f'{parent}\data\genome_tags.csv')
genome_tags.sample(5)
# Out:
#       tagId                 tag
# 888     889     science fiction
# 1064   1065          us history
# 365     366  exceptional acting
# 914     915            shopping
# 227     228         colonialism

# %%
# Other global performance measures

link = pd.read_csv(f'{parent}\data\link.csv')
link.sample(5)
# Out:
#        movieId  imdbId    tmdbId
# 6661      6771  362511   18113.0
# 2205      2290   81554   11337.0
# 10830    43710   36126   37631.0
# 17993    90258   91359  337435.0
# 6874      6986   16641   31510.0

# %%
# Movie information

movie = pd.read_csv(f'{parent}\data\movie.csv')
movie.sample(5)
# Out:
#        movieId                            title                         genres
# 16291    82261    Breaking the Maya Code (2008)                    Documentary
# 24752   116959                 Embracing (1992)                    Documentary
# 11531    49985  The Face Behind the Mask (1941)  Crime|Drama|Film-Noir|Romance
# 27193   131015                  Hellgate (2011)                Horror|Thriller
# 11089    46156    Ax, The (couperet, Le) (2005)                   Comedy|Crime

# %%
# Ratings of movies by "users"

rating = pd.read_csv(fr'{parent}\data\rating.csv')
rating.sample(5)
# Out:
#           userId  movieId  rating            timestamp
# 16634030  115082      293     5.0  2000-12-11 20:01:33
# 17115246  118358     3671     4.5  2005-03-17 13:11:59
# 433159      2945       34     3.0  2009-05-14 01:22:58
# 10734922   74226     1732     4.0  2005-11-17 15:54:22
# 19607755  135748     3710     1.0  2001-06-21 15:57:47

# %%
# Tags applied to movies by "users"

tag = pd.read_csv(fr'{parent}\data\tag.csv')
tag.sample(5)
# Out:
#         userId  movieId               tag            timestamp
# 352615  108248    50872     setting:Paris  2009-04-29 12:56:23
# 256702   75242    44191              1984  2006-04-02 11:20:24
# 416198  124998   103384  ridicules heroes  2014-04-10 19:57:02
# 225145   68558    56715           suicide  2010-11-13 17:24:22
# 319010   93009     8640            boring  2010-10-23 15:53:02

# %% [markdown]
# ### Plan of attack

# %% [markdown]
# <img src = "https://miro.medium.com/max/950/1*0ygb2uJknG6FdYT1vZqnsg.png"> </img>
